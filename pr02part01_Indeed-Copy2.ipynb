# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
def compile_URL(job,city):
    """
    """
    base_url = 'http://www.indeed.com/jobs?q='
    add_1_job= job
    add_precity = '&l='
    add_2_city=city
    return (base_url + add_1_job + add_precity + add_2_city)

# %%
def bring_soup(url):
    html_source= requests.get(url)
    soup = BeautifulSoup(html_source.content, 'html.parser', from_encoding="utf-8")
    return soup

# %%
def title_column(soup):
    col_title =[]
    for itersoup in soup.find_all(class_= "result" ):
        # - - - - 
        try:
            itertitle = itersoup.find(class_='jobtitle').text.replace('\n', '')
        except:
            itertitle='None'
        # - - - - 
        col_title.append(itertitle)
        
    return col_title

# %%
def location_column(soup):
    col_location  = [ ]
    for itersoup in soup.find_all(class_= "result" ):
            try:
                location = itersoup.find('span', {'class':"location" }).text.replace('\n', '')
            except:
                location = 'None'
#             - - -
            col_location.append(location)
    return col_location

# %%
def company_column(soup):
    col_company  = [ ]
    for itersoup in soup.find_all(class_= "result" ):
            try:
                company = itersoup.find(class_='company').text.replace('\n','')
            except:
                company = 'None'
#             - - -
            col_company.append(company.strip())
    return col_company

# %%
def desc_column(soup):
    col_desc  = [ ]
    for itersoup in soup.find_all(class_= "result" ):
            try:
                description = itersoup.find('span', {'class':'summary'}).text.replace('\n', '')
            except:
                description = 'None'
#             - - -
            col_desc.append(description.strip())
    return col_desc

# %%
def url_column(soup):
    col_href = []
    base_url = 'http://www.indeed.com'
    for iterfoo in soup.find_all(class_= "result" ):
        try:
            href = iterfoo.find('a')['href']
            col_href.append((base_url+href).strip())
        except:
            href='None'
            col_href.append(href)
        
    return list(col_href)
    #     print('http://www.indeed.com'+href)

# %%
def frame_indeed(soup):
    return pd.DataFrame({'Title': title_column(soup),
              'Company': company_column(soup),
              'Location': location_column(soup),
              'Description': desc_column(soup),
              'URLs': url_column(soup)})

# %%
# compile_URL('developer','denver')
def parse_n_frame(url):
    soup = bring_soup(url)
    return pd.DataFrame({'Title': title_column(soup),
              'Company': company_column(soup),
              'Location': location_column(soup),
              'Description': desc_column(soup),
              'URLs': url_column(soup)})
#=============================
dev_denver_url = compile_URL('developer',
                             'denver'
                            )
#=============================
parse_n_frame(dev_denver_url)
# Out:
#                                                 Title  \
# 0                                 Front End Developer
# 1         Senior ASP.NET MVC Developer with ecommerce
# 2              Software Developer Mobile Applications
# 3                                        UI Developer
# 4   Engineer, Software Development - Video Technology
# 5                            Quickbase Technical Lead
# 6                                         Developer I
# 7                    Job Developer/Research Associate
# 8                              User Content Developer
# 9                                 Front End Developer
# 10                        Junior HTML Email Developer
# 11                   Email and Landing Page Developer
# 12                            Junior Web UI Developer
# 13                          Junior Developer - Appian
# 14  OppenheimerFunds Technology Associate Program ...
# 15                                  Product Developer
# 16                           Cloud Platform Developer
# 17                                 Software Developer
#
#                                 Company  \
# 0                    Bayshore Solutions
# 1                    Bayshore Solutions
# 2                         SCRAM Systems
# 3                       CGI Group, Inc.
# 4                              T-Mobile
# 5        VeilSun Inc. - Denver Colorado
# 6   State of Colorado Job Opportunities
# 7      ReEntry Rehabilitations Services
# 8                               Sopheon
# 9                   Creative Alignments
# 10           PIN Business Network, Inc.
# 11                               Ibotta
# 12                          DealersLink
# 13                        Bits In Glass
# 14                     OppenheimerFunds
# 15                               DANONE
# 16                                 Xero
# 17                        SCRAM Systems
#
#                                        Location  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
# 5                                          None
# 6                                    Denver, CO
# 7                                  Lakewood, CO
# 8                                    Denver, CO
# 9       Denver, CO 80205 (Northern Denver area)
# 10  Denver, CO 80237 (Southeastern Denver area)
# 11                 Denver, CO 80202 (Lodo area)
# 12                               Broomfield, CO
# 13                 Denver, CO 80202 (Lodo area)
# 14                                   Denver, CO
# 15                               Louisville, CO
# 16                                         None
# 17                                         None
#
#                                           Description  \
# 0   Front End Developer- downtown Denver. In this ...
# 1   The Developer is responsible for developing we...
# 2   Job Description: The right candidate will have...
# 3   We are seeking a UI Developer who will be work...
# 4   The Technology Software Engineer will work wit...
# 5   People who have been Project Managers, Busines...
# 6   The developer operates at the application leve...
# 7   Collect labor market information regarding job...
# 8   As a User Content Developer at Sopheon, you wi...
# 9   Proven experience as a Front-End Developer. Yo...
# 10  Work with art directors, production designers,...
# 11  The Email and Landing Page Developer will repo...
# 12  The UI developer will work hand in hand with a...
# 13  As a Junior Developer you will focus on the ba...
# 14  Developer Track - Skills/Qualifications:. In o...
# 15  USD - Dannon in ESSENTIAL DAIRY & PLANT-BASED ...
# 16  Familiarity with agile software development me...
# 17  Also teaches and mentors more junior software ...
#
#                                                  URLs
# 0   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 2   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 3   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 4   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 5   http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 6   http://www.indeed.com/rc/clk?jk=2fcb03379102fd...
# 7   http://www.indeed.com/rc/clk?jk=d3a218e10bea1b...
# 8   http://www.indeed.com/rc/clk?jk=213e3842a97cb8...
# 9   http://www.indeed.com/rc/clk?jk=cc54ec7954a836...
# 10  http://www.indeed.com/company/DoBizLo/jobs/Jun...
# 11  http://www.indeed.com/rc/clk?jk=1cbf22a7231f19...
# 12  http://www.indeed.com/rc/clk?jk=472302834b6c44...
# 13  http://www.indeed.com/rc/clk?jk=aa96edb9b59d1e...
# 14  http://www.indeed.com/rc/clk?jk=e1846f7a757c96...
# 15  http://www.indeed.com/rc/clk?jk=2ee2de75d04ca0...
# 16  http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 17  http://www.indeed.com/pagead/clk?mo=r&ad=-6NYl...
